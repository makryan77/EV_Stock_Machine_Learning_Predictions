# %% [markdown]
# # Importing Python libraries

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
from matplotlib import cm
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from sklearn.preprocessing import MinMaxScaler   ## For scaling the data
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Dropout   ## importing layers of Neural network
from keras.callbacks import ModelCheckpoint     ## imporing modelcheck pointer
from keras.losses import MSE                  ## importing error function
from keras.optimizers import Adam              ## importing optimizer
from keras.activations import relu           ## importing activation function



import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h6>"</h6>
#     <h6>"</h6>
#     <h6>"</h6>
#     <h6>"</h6>
#     <h6>"</h6>
# <h1><center><strong> TSLA Stock</strong></center></h1>
#     <h6>"</h6>
#     <h6>"</h6>
#     <h6>"</h6>
#     <h6>"</h6>
#     <h6>"</h6>
#
# </div>

# %% [markdown]
# # Loading dataset

# %%
data = pd.read_csv('TSLA_Stock.csv')

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# <h1><center> Modelling LSTM</center></h1>

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Selecting the Close price

# %%
df = data['Close'].values
print("Total No. of days of Stock :",df.shape[0])
# Out:
# Total No. of days of Stock : 2517

# %% [markdown]
# ### Splitting the data into train test split

# %%
dataset_train = np.array(df[:int(df.shape[0]*0.8)])
dataset_test = np.array(df[int(df.shape[0]*0.8)-50:])
print('Training stock :',dataset_train.shape[0],'days')
print('Test stock :',dataset_test.shape[0],'days')
# Out:
# Training stock : 2013 days
# Test stock : 554 days

# %% [markdown]
# #### Scaling the data

# %% [markdown]
# a) Train Data

# %%
scaler = MinMaxScaler(feature_range=(0,1))
dataset_train = scaler.fit_transform(dataset_train.reshape(-1, 1))

# %% [markdown]
# b) Test Data

# %%
dataset_test = scaler.transform(dataset_test.reshape(-1, 1))

# %% [markdown]
# ### Function to prepare data for the LSTM

# %%
def create_dataset(df,n):
    x = []
    y = []
  
    for i in range(n, df.shape[0]):
        x.append(df[i-n:i, 0])
        y.append(df[i, 0])
    x = np.array(x)
    y = np.array(y)
    return x,y

# %%
x_train, y_train = create_dataset(dataset_train,50)

# %%
x_test, y_test = create_dataset(dataset_test,50)

# %% [markdown]
# #### Reshape features for LSTM Layer

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

# %%
print('Training data shape',x_train.shape)
print('Test data shape',x_test.shape)
# Out:
# Training data shape (1963, 50, 1)
# Test data shape (504, 50, 1)

# %% [markdown]
# # Building LSTM Model

# %%
model = Sequential()

model.add(LSTM(units=96, 
               return_sequences=True,
               input_shape=(x_train.shape[1], 1)))

model.add(Dropout(0.2))

model.add(LSTM(units=96, 
               return_sequences=True))

model.add(Dropout(0.2))

model.add(LSTM(units=96, 
               return_sequences=True))

model.add(Dropout(0.2))

model.add(LSTM(units=96))

model.add(Dropout(0.2))

model.add(Dense(units=1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50, 96)            37632
# _________________________________________________________________
# dropout (Dropout)            (None, 50, 96)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50, 96)            74112
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50, 96)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50, 96)            74112
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50, 96)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 96)                74112
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 96)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 97
# =================================================================
# Total params: 260,065
# Trainable params: 260,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=MSE, optimizer=Adam())

# %%
checkpointer = ModelCheckpoint(filepath='nio.stock_prediction.hdf5',save_best_only=True,verbose=1)
callbacks = [checkpointer]

# %%
history = model.fit(x_train,y_train,batch_size=32,epochs=70,verbose=1,callbacks=[checkpointer],validation_split=0.05)
# Out:
# Epoch 1/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0253- ETA: 0s - loss: 0.0
# Epoch 00001: val_loss improved from inf to 0.00896, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 16s 264ms/step - loss: 0.0253 - val_loss: 0.0090
# Epoch 2/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 00002: val_loss improved from 0.00896 to 0.00353, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 13s 226ms/step - loss: 0.0046 - val_loss: 0.0035
# Epoch 3/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 00003: val_loss did not improve from 0.00353
# 59/59 [==============================] - 14s 229ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 4/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 00004: val_loss improved from 0.00353 to 0.00297, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 14s 230ms/step - loss: 0.0047 - val_loss: 0.0030
# Epoch 5/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 00005: val_loss did not improve from 0.00297
# 59/59 [==============================] - 10s 175ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 6/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0039- ETA: 1s - loss:
# Epoch 00006: val_loss improved from 0.00297 to 0.00275, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 11s 187ms/step - loss: 0.0039 - val_loss: 0.0027
# Epoch 7/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0038- ETA: 2s
# Epoch 00007: val_loss improved from 0.00275 to 0.00263, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 12s 204ms/step - loss: 0.0038 - val_loss: 0.0026
# Epoch 8/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 00008: val_loss improved from 0.00263 to 0.00248, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 13s 217ms/step - loss: 0.0038 - val_loss: 0.0025
# Epoch 9/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00009: val_loss did not improve from 0.00248
# 59/59 [==============================] - 10s 173ms/step - loss: 0.0035 - val_loss: 0.0039
# Epoch 10/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00010: val_loss improved from 0.00248 to 0.00218, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 11s 183ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 11/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 00011: val_loss improved from 0.00218 to 0.00195, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 12s 202ms/step - loss: 0.0038 - val_loss: 0.0019
# Epoch 12/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00012: val_loss improved from 0.00195 to 0.00193, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 10s 172ms/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 13/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00013: val_loss did not improve from 0.00193
# 59/59 [==============================] - 10s 168ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 14/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00014: val_loss improved from 0.00193 to 0.00168, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 11s 184ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 15/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00015: val_loss did not improve from 0.00168
# 59/59 [==============================] - 12s 199ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 16/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00016: val_loss did not improve from 0.00168
# 59/59 [==============================] - 11s 180ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 17/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0028- ETA: 2s
# Epoch 00017: val_loss did not improve from 0.00168
# 59/59 [==============================] - 11s 178ms/step - loss: 0.0028 - val_loss: 0.0019
# Epoch 18/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00018: val_loss improved from 0.00168 to 0.00135, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 11s 192ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 19/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00019: val_loss improved from 0.00135 to 0.00127, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 11s 188ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 20/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00020: val_loss did not improve from 0.00127
# 59/59 [==============================] - 11s 186ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 21/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00021: val_loss did not improve from 0.00127
# 59/59 [==============================] - 11s 191ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 22/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00022: val_loss improved from 0.00127 to 0.00117, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 11s 187ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 23/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00023: val_loss did not improve from 0.00117
# 59/59 [==============================] - 12s 208ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 24/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00024: val_loss did not improve from 0.00117
# 59/59 [==============================] - 12s 198ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 25/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00025: val_loss did not improve from 0.00117
# 59/59 [==============================] - 12s 198ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 26/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00026: val_loss did not improve from 0.00117
# 59/59 [==============================] - 11s 186ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 27/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00027: val_loss did not improve from 0.00117
# 59/59 [==============================] - 13s 223ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 28/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00028: val_loss improved from 0.00117 to 0.00104, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 12s 195ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 29/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0019- ETA: 1s - loss:
# Epoch 00029: val_loss did not improve from 0.00104
# 59/59 [==============================] - 11s 185ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 30/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00030: val_loss did not improve from 0.00104
# 59/59 [==============================] - 11s 187ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 31/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00031: val_loss improved from 0.00104 to 0.00101, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 11s 186ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 32/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00032: val_loss improved from 0.00101 to 0.00094, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 11s 182ms/step - loss: 0.0022 - val_loss: 9.3879e-04
# Epoch 33/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00033: val_loss did not improve from 0.00094
# 59/59 [==============================] - 13s 220ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 34/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00034: val_loss did not improve from 0.00094
# 59/59 [==============================] - 10s 177ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 35/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00035: val_loss did not improve from 0.00094
# 59/59 [==============================] - 11s 187ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 36/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00036: val_loss did not improve from 0.00094
# 59/59 [==============================] - 11s 182ms/step - loss: 0.0019 - val_loss: 9.6108e-04
# Epoch 37/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00037: val_loss improved from 0.00094 to 0.00088, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 11s 185ms/step - loss: 0.0016 - val_loss: 8.7718e-04
# Epoch 38/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00038: val_loss improved from 0.00088 to 0.00080, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 11s 183ms/step - loss: 0.0018 - val_loss: 8.0183e-04
# Epoch 39/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00039: val_loss did not improve from 0.00080
# 59/59 [==============================] - 13s 221ms/step - loss: 0.0019 - val_loss: 9.9131e-04
# Epoch 40/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00040: val_loss did not improve from 0.00080
# 59/59 [==============================] - 11s 184ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 41/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00041: val_loss did not improve from 0.00080
# 59/59 [==============================] - 12s 199ms/step - loss: 0.0016 - val_loss: 8.3752e-04
# Epoch 42/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00042: val_loss improved from 0.00080 to 0.00075, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 11s 183ms/step - loss: 0.0016 - val_loss: 7.5385e-04
# Epoch 43/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00043: val_loss improved from 0.00075 to 0.00072, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 10s 172ms/step - loss: 0.0015 - val_loss: 7.1751e-04
# Epoch 44/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00044: val_loss did not improve from 0.00072
# 59/59 [==============================] - 10s 166ms/step - loss: 0.0015 - val_loss: 7.3516e-04
# Epoch 45/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00045: val_loss did not improve from 0.00072
# 59/59 [==============================] - 10s 176ms/step - loss: 0.0016 - val_loss: 8.1405e-04
# Epoch 46/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00046: val_loss improved from 0.00072 to 0.00064, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 10s 177ms/step - loss: 0.0014 - val_loss: 6.4492e-04
# Epoch 47/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0016-
# Epoch 00047: val_loss did not improve from 0.00064
# 59/59 [==============================] - 12s 200ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 48/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00048: val_loss did not improve from 0.00064
# 59/59 [==============================] - 11s 178ms/step - loss: 0.0015 - val_loss: 7.6257e-04
# Epoch 49/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00049: val_loss improved from 0.00064 to 0.00063, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 10s 170ms/step - loss: 0.0013 - val_loss: 6.2570e-04
# Epoch 50/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00050: val_loss improved from 0.00063 to 0.00060, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 11s 179ms/step - loss: 0.0013 - val_loss: 6.0252e-04
# Epoch 51/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00051: val_loss did not improve from 0.00060
# 59/59 [==============================] - 10s 175ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 52/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00052: val_loss did not improve from 0.00060
# 59/59 [==============================] - 10s 177ms/step - loss: 0.0015 - val_loss: 6.8134e-04
# Epoch 53/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00053: val_loss did not improve from 0.00060
# 59/59 [==============================] - 11s 180ms/step - loss: 0.0015 - val_loss: 7.6155e-04
# Epoch 54/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00054: val_loss did not improve from 0.00060
# 59/59 [==============================] - 12s 197ms/step - loss: 0.0014 - val_loss: 6.3295e-04
# Epoch 55/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00055: val_loss did not improve from 0.00060
# 59/59 [==============================] - 10s 168ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 56/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00056: val_loss did not improve from 0.00060
# 59/59 [==============================] - 10s 171ms/step - loss: 0.0015 - val_loss: 6.8235e-04
# Epoch 57/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00057: val_loss did not improve from 0.00060
# 59/59 [==============================] - 12s 197ms/step - loss: 0.0014 - val_loss: 6.8872e-04
# Epoch 58/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00058: val_loss improved from 0.00060 to 0.00057, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 11s 184ms/step - loss: 0.0014 - val_loss: 5.7064e-04
# Epoch 59/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00059: val_loss did not improve from 0.00057
# 59/59 [==============================] - 10s 173ms/step - loss: 0.0014 - val_loss: 6.3645e-04
# Epoch 60/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00060: val_loss improved from 0.00057 to 0.00056, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 10s 169ms/step - loss: 0.0014 - val_loss: 5.5703e-04
# Epoch 61/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00061: val_loss did not improve from 0.00056
# 59/59 [==============================] - 11s 188ms/step - loss: 0.0014 - val_loss: 5.8394e-04
# Epoch 62/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 00062: val_loss improved from 0.00056 to 0.00055, saving model to nio.stock_prediction.hdf5
# 59/59 [==============================] - 10s 173ms/step - loss: 0.0012 - val_loss: 5.4845e-04
# Epoch 63/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00063: val_loss did not improve from 0.00055
# 59/59 [==============================] - 10s 172ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 64/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00064: val_loss did not improve from 0.00055
# 59/59 [==============================] - 10s 169ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 65/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00065: val_loss did not improve from 0.00055
# 59/59 [==============================] - 11s 178ms/step - loss: 0.0013 - val_loss: 6.1507e-04
# Epoch 66/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 00066: val_loss did not improve from 0.00055
# 59/59 [==============================] - 11s 181ms/step - loss: 0.0012 - val_loss: 6.2581e-04
# Epoch 67/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 00067: val_loss did not improve from 0.00055
# 59/59 [==============================] - 11s 181ms/step - loss: 0.0012 - val_loss: 5.7057e-04
# Epoch 68/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00068: val_loss did not improve from 0.00055
# 59/59 [==============================] - 11s 189ms/step - loss: 0.0013 - val_loss: 7.1873e-04
# Epoch 69/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 00069: val_loss did not improve from 0.00055
# 59/59 [==============================] - 11s 192ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 70/70
# 59/59 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 00070: val_loss did not improve from 0.00055
# 59/59 [==============================] - 14s 235ms/step - loss: 0.0012 - val_loss: 6.5435e-04

# %% [markdown]
# ### 5. Visualizing Results

# %% [markdown]
# #### Plotting the Predicted Stock Price with True Stock Price

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

fig, ax = plt.subplots(figsize=(35,10))
plt.plot(df, color='red',  label="True Stock Price",)
ax.plot(range(len(y_train)+50,len(y_train)+50+len(predictions)),predictions, color='blue', label='Predicted Stock Price')
plt.legend()

# %%
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))


fig, ax = plt.subplots(figsize=(35,10))
ax.plot(y_test_scaled, color='red', label='True Stock Price')
plt.plot(predictions, color='blue', label='Predicted Stock Price')
plt.legend()

# %% [markdown]
# The Graph looks beautiful !!

# %% [markdown]
# ## Evaluation

# %%
data.reset_index(inplace=True)
comparison = data[['date','Close']].iloc[len(y_train)+50:] 
comparison['Predictions'] = predictions

# %% [markdown]
# ### MSE

# %%
LR_test_mse=mean_squared_error(comparison['Close'],comparison['Predictions'])
print('Mean Squared Error: ', round(LR_test_mse,5))
# Out:
# Mean Squared Error:  76123.06736

# %% [markdown]
# ### MAE

# %%
LR_test_MAE=mean_absolute_error(comparison['Close'],comparison['Predictions'])
print('Mean Absolute Error: ', round(LR_test_MAE,5))
# Out:
# Mean Absolute Error:  189.33374
